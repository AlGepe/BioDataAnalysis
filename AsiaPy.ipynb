# %%
from collections import Counter
from os import listdir
from copy import deepcopy as dcopy

# %%
#############################################
#       Read File and get dictionary        #
#############################################
#
#  *INPUT:  Name of file
#
#  *OUTPUT: 2-D list of dictionaries
#           0th => Reactants : Occurrencies
#           1st => Products  : Occurrencies
#
#
############################################
#        Read File and get dictionary      #
############################################

def file2dict(nameString) :

    thaFile = open(nameString, 'rU')
    log = open("log.out",'w')
    allLines = thaFile.readlines()
    noLines = len(allLines)
    isReact = False
    prodOrReact = False
    isProd = False
    isGood = False
    reactants = []
    compound = ""
    products = []
    i = 0
    
    for line in allLines: # Read all file

        if not prodOrReact : # line is not part of list of prods/react
            
            if line.find('<listOfProducts>') > 0:
                
                prodOrReact = True
                log.write("in")
                isProd = True
                
            if line.find('<listOfReactants>') > 0:
                
                prodOrReact = True
                log.write("in")
                isReact = True

        # Look for Compounds if its time for that
        if prodOrReact : # inside list of prod/react
            
            # Check is list has ended here
            if line.find('</listOfReactants>') > 0:
                
                prodOrReact = False
                log.write("out"+'\n')
                isReact = False
                
            elif line.find('</listOfProducts>') > 0:
                
                prodOrReact = False
                log.write("out"+'\n')
                isProd = False
                
            else : # we are in list
                
                isGood = line.find('speciesReference species=')
                
                if isGood > -1:
                    
                    endProd = line.find('"',isGood+27)
                    compound = line[isGood+26:endProd]
                    
                    if isReact :
                        reactants.append(compound)#Add to reactantsList
                    elif isProd :
                        products.append(compound)#Add to products:ist               
    
    # Convert list into dictionary of occurences
    dictReactants = Counter(reactants)
    dictProducts = Counter(products)
    compounds = [dictReactants, dictProducts]
    thaFile.close()
    return compounds

# %%
############################################
#   Get all Dictionaries from Filenames    #
############################################
#
#  *INPUT: 1-D list of filenames
#
#  *OUTPUT: 2-D list of dictionaries
#           0th => Reactants
#           1st => Products
#  Info: Dictionaries are 2-D with 
#        Key == Name of Bacteria
#        Value == Dict of comp : #appear
#
#
############################################
#   Get all Dictionaries from Filenames    #
############################################

def dict4all(allFiles) :
    
    allProds = {}
    allReact = {}
    allInDict = []
    
    for currentFile in allFiles :
        
        absPath = 'ExampleFiles/'+currentFile
        simpDict = file2dict(absPath)
        allReact[currentFile[:-4]] = simpDict[0]
        allProds[currentFile[:-4]] = simpDict[1]
        
        
    allInDict.append(allReact)
    allInDict.append(allProds)
    return allInDict

# %%
############################################
#       Get Matches Human-Bateria          #
############################################
#
#  *INPUT: Dictionary of dictionaries
#          Key == Name of Bacteria
#          Value == Name comp : #appear
#
#  *OUTPUT: Dictionary of Compounds in 
#           humansANDbacteria 
#           Compound name: # bacterias
#
#  Info: Humans is an entry in dictionary of
#        the input list (INPUT['humans'])
#
############################################
#       Get Matches Human-Bateria          #
############################################

def getMatches(everyCompDict) :
    
    matches = []
    humans = everyCompDict['humans']
    del everyCompDict['humans']
    
    for compound in humans :
        for bacteria in everyCompDict : 
            if compound in everyCompDict[bacteria] : # Compounds appears in bacteria and humans
                matches.append(compound)
                
    everyCompDict['humans'] = humans
    dictMatches = Counter(matches)
    return dictMatches

# %%
############################################
#       Apply cuts on Dictionaries         #
############################################
#
#  *INPUT: -Dictionary of type:
#            dict[Key] == Value   
#          - Maximum Value allowed
#          - Minimum Value allowed
#
#  *OUTPUT: Trimmed-down dictionary
#
#  Info: -It is required that: 
#         value == [Number]
#        -Remaining entries satisfy:
#         value < maxVal
#         value > minVal
#
#
############################################
#       Apply cuts on Dictionaries         #
############################################

def dictCutOff(thisDict, maxVal, minVal) :#
    
    dictTrim = copy.deepcopy(thisDict)
    
    if maxVal < minVal :
        temp = copy.deepcopy(maxVal)
        maxVal = minVal
        minVal = temp
    elif maxVal == minVal :
        print "Error: Invalid input limits [They are the same you moron]"
        return
    for compound in thisDict : 
        if any ([dictTrim[compound] >= maxVal, dictTrim[compound] <= minVal]) :
            del dictTrim[compound]
    
    return dictTrim

# %%
############################################
#        Sum All Dictionary Entries        #
############################################
#
#  *INPUT: -Dictionary (key : [number])
#
#  *OUTPUT: Sum of values [number]
#
#
############################################
#        Sum All Dictionary Entries        #
############################################

def sumDict(dict2Sum) :
    
    total = 0
    for molec in dict2Sum:
        total += dict2Sum[molec]
    return total*1.0

# %%
############################################
#        Help-printing for infoMolec       #
############################################
#
#  *INPUT: -None
#
#  *OUTPUT: -None
#
#  Info: -Prints information about usage and
#         inner workings of infoMolec
#        -Information is sorted in 3 topics:
#           *input
#           *output
#           *inner_workings
#
#
############################################
#        Help-printing for infoMolec       #
############################################
def helpInfoMolec():
    
    print "############################################"
    print "#        Info-Getter for molecules         #"
    print "#                                          #"
    print "#  HELP Section: Information about inner   #"
    print "# working and usage of infoMolec function  #"
    print "############################################"
    print "#"
    print "#-------------------------------------------"
    print "#          BASIC INFORMATION"
    print "#-------------------------------------------"
    print "#"
    print "#  *INPUT: -Name of molecule"
    print "#          -Dictionary of dictionaries "
    print "#           for reactants OR products"
    print "#"
    print "#  *OUTPUT: Dictionary of molecule info"
    print "#           such as:"
    print "#           _list of bacterias in which "
    print "#             it appears"
    print "#             appearances : list[]"
    print "#           _appearances in humans"
    print "#            humans : [#, %]"
    print "#           _appearances in each bacteria"
    print "#            bacteriaName : [#, %]"
    print "#           _total appearances in bacteria"
    print "#            bacterias : #"
    print "#"
    print "#  Extra: Input list of dict of dict in the "
    print "#        form of list[0] or list[1] from"
    print "#        OUTPUT in dict4all function"
    print "#"
    print "#"
    print "############################################"
    print "#        Info-Getter for molecules         #"
    print "############################################"
    print ""
    print ""
    print " For extra information please select the topic by typing one of the following keywords: "
    print " Keywords:  input \t output \t inner_workings"
    topic = raw_input('Select topic: ')
    topicSelected = False
    while not topicSelected :
        if topic == 'input' :
            topicSelected = True
            print topic
        elif topic == 'output':
            topicSelected = True
            print topic
        elif topic == 'inner_workings':
            topicSelected = True
            print topic
        else :
            print "Topic could not be selected, please try again:"
            topic = raw_input('Select topic: ')

# %%
############################################
#        Info-Getter for molecules         #
############################################
#
#  *INPUT: -Name of molecule
#          -Dictionary of dictionaries 
#           for reactants OR products
#
#  *OUTPUT: Dictionary of molecule info
#           such as:
#           _list of bacterias in which 
#             it appears
#             appearances : list[]
#           _appearances in humans
#            humans : [#, %]
#           _appearances in each bacteria
#            bacteriaName : [#, %]
#           _total appearances in bacteria
#            bacterias : #
#
#  Info: Input list of dict of dict in the 
#        form of list[0] or list[1] from
#        OUTPUT in dict4all function
#
#
############################################
#        Info-Getter for molecules         #
############################################

def infoMolec(molecule = 0, dictioData = 0):
    if all([dictioData != 0, molecule != 0]):

        manyStats = {}
        listOfBact = []
        humanStats = []
        bactStats = {}
        tempBactDict = {}
        allBactStats = {}  
        nameLen = 0

        '''
            List of Bacterias 
        '''
        for bacteria in dictioData :
            if molecule in dictioData[bacteria] :
                listOfBact.append(bacteria)
                if nameLen < len(bacteria) :
                    nameLen = len(bacteria)
        print nameLen

        manyStats['allBacteria'] = listOfBact

        '''
         Appearances in humans
        '''
        humanStats.append(dictioData['humans'][molecule])
        sumHumans = sumDict(dictioData['humans'])

        humanStats.append(1.0 * humanStats[0]/sumHumans)

        manyStats['humans'] = humanStats

        print "Molecule "+molecule+" appears {0} times in human reaction".format(humanStats[0])
        print "Represents {0:3f}% of total in humans".format(humanStats[1]*100)
        print "=================================="

        '''
            Total Appearances in all Bacteria
        '''

        for bacteria in listOfBact :

                tempBactDict[bacteria] = dictioData[bacteria][molecule]

        totalAppear = sumDict(tempBactDict)

        manyStats['appearancesBacteria'] = totalAppear

        '''
            Appearances in bacterias 
        '''

        for bacteria in tempBactDict :
            bactStats[bacteria] = [tempBactDict[bacteria], tempBactDict[bacteria]/totalAppear]


        manyStats['bacterias'] = bactStats
        #print nameLen

        print "Molecule ' "+molecule+" ' appears in: "
        print "{0:59} \t Appearances "+'\t'+"Percetange ".format('Bacteria')
        for bacteria in bactStats :
            print "{0:59} : {1:3} times => {2:3f}% of total appearences".format(bacteria, bactStats[bacteria][0], bactStats[bacteria][1]*100)

        print "=================================="


        '''
            Work done, lay back and enjoy results
        '''
        return manyStats
    
    '''
        On-screen help / manual
    '''
    else : #this is help on-screen
        helpInfoMolec()
        return
# Out:
#   File "<ipython-input-35-cac0cbc7d740>", line 106
#     else : #this is help on-screen
#        ^
# SyntaxError: invalid syntax

# %%
infoMolec()
# Out:
# ############################################
# #        Info-Getter for molecules         #
# #                                          #
# #  HELP Section: Information about inner   #
# # working and usage of infoMolec function  #
# ############################################
# #
# #-------------------------------------------
# #          BASIC INFORMATION
# #-------------------------------------------
# #
# #  *INPUT: -Name of molecule
# #          -Dictionary of dictionaries
# #           for reactants OR products
# #
# #  *OUTPUT: Dictionary of molecule info
# #           such as:
# #           _list of bacterias in which
# #             it appears
# #             appearances : list[]
# #           _appearances in humans
# #            humans : [#, %]
# #           _appearances in each bacteria
# #            bacteriaName : [#, %]
# #           _total appearances in bacteria
# #            bacterias : #
# #
# #  Extra: Input list of dict of dict in the
# #        form of list[0] or list[1] from
# #        OUTPUT in dict4all function
# #
# #
# ############################################
# #        Info-Getter for molecules         #
# ############################################
#
#
#  For extra information please select the topic by typing one of the following keywords:
#  Keywords:  input 	 output 	 inner_workings
# Select topic: tete
# Topic could not be selected, please try again:
# Select topic: nope
# Topic could not be selected, please try again:
# Select topic: topic
# Topic could not be selected, please try again:
# Select topic: input
# input

# %%
allThemFiles = listdir('ExampleFiles')
allThemDicts = []
allThemDicts = dict4all(allThemFiles)
#print getMatches(allThemDicts[0])

# %%
#humanoids = allThemDicts[0]['humans']
allReact = allThemDicts[0]
#print sumDict(humanoids)
infoMolec('M_hmgcoa_c', allReact)
# Out:
# 59
# Molecule M_hmgcoa_c appears 3 times in human reaction
# Represents 0.019136% of total in humans
# ==================================
# Molecule ' M_hmgcoa_c ' appears in:
# {0:59} 	 Appearances 	Percetange
# Porphyromonas_gingivalis_W83                                :   2 times => 0.402414% of total appearences
# Scardovia_inopinata_F0304                                   :   2 times => 0.402414% of total appearences
# Lactobacillus_amylolyticus_DSM_11664                        :   1 times => 0.201207% of total appearences
# Streptococcus_anginosus_1_2_62CV                            :   1 times => 0.201207% of total appearences
# Staphylococcus_lugdunensis_HKU09_01                         :   2 times => 0.402414% of total appearences
# Lactobacillus_ultunensis_DSM_16047                          :   1 times => 0.201207% of total appearences
# Fusobacterium_ulcerans_ATCC_49185                           :   1 times => 0.201207% of total appearences
# Bacillus_infantis_NRRL_B_14911                              :   1 times => 0.201207% of total appearences
# Microbacterium_paraoxydans_77MFTsu3_2                       :   1 times => 0.201207% of total appearences
# Lactococcus_garvieae_ATCC_49156                             :   2 times => 0.402414% of total appearences
# Weissella_cibaria_KACC_11862                                :   2 times => 0.402414% of total appearences
# Streptococcus_intermedius_JTH08                             :   2 times => 0.402414% of total appearences
# Lactobacillus_brevis_ATCC_367                               :   1 times => 0.201207% of total appearences
# Lactobacillus_reuteri_SD2112_ATCC_55730                     :   1 times => 0.201207% of total appearences
# Acinetobacter_calcoaceticus_PHEA_2                          :   2 times => 0.402414% of total appearences
# Gemella_sanguinis_M325                                      :   2 times => 0.402414% of total appearences
# Kurthia_massiliensis_JC30                                   :   2 times => 0.402414% of total appearences
# Aeromonas_media_WS                                          :   2 times => 0.402414% of total appearences
# Lactobacillus_reuteri_F275_JCM_1112                         :   1 times => 0.201207% of total appearences
# Brevibacterium_massiliense_5401308                          :   1 times => 0.201207% of total appearences
# Lactobacillus_gastricus_PS3                                 :   2 times => 0.402414% of total appearences
# Weissella_confusa_LBAE_C39_2                                :   2 times => 0.402414% of total appearences
# Propionibacterium_propionicum_F0230a                        :   2 times => 0.402414% of total appearences
# Afipia_birgiae_34632                                        :   3 times => 0.603622% of total appearences
# Streptococcus_mutans_ATCC_25175                             :   2 times => 0.402414% of total appearences
# Lactobacillus_helveticus_DPC_4571                           :   2 times => 0.402414% of total appearences
# Streptococcus_parasanguinis_ATCC_903                        :   2 times => 0.402414% of total appearences
# Enterococcus_faecalis_TX1322                                :   1 times => 0.201207% of total appearences
# Lactobacillus_jensenii_1153                                 :   2 times => 0.402414% of total appearences
# Streptococcus_thermophilus_LMG_18311                        :   1 times => 0.201207% of total appearences
# Alcaligenes_faecalis_subsp_faecalis_NBRC_13111              :   1 times => 0.201207% of total appearences
# Anaerobaculum_hydrogeniformans_OS1_ATCC_BAA_1850            :   2 times => 0.402414% of total appearences
# Lactobacillus_ruminis_ATCC_25644                            :   1 times => 0.201207% of total appearences
# Brevundimonas_diminuta_470_4                                :   2 times => 0.402414% of total appearences
# Halococcus_morrhuae_DSM1307                                 :   3 times => 0.603622% of total appearences
# Enterococcus_faecalis_V583                                  :   1 times => 0.201207% of total appearences
# Streptococcus_mitis_NCTC_12261                              :   2 times => 0.402414% of total appearences
# Lactobacillus_paracasei_subsp_paracasei_ATCC_25302          :   1 times => 0.201207% of total appearences
# Enterococcus_avium_ATCC_14025                               :   2 times => 0.402414% of total appearences
# Staphylococcus_epidermidis_ATCC_12228                       :   2 times => 0.402414% of total appearences
# Bacillus_firmus_DS1                                         :   1 times => 0.201207% of total appearences
# Clostridium_symbiosum_WAL_14163                             :   1 times => 0.201207% of total appearences
# Yersinia_pseudotuberculosis_YPIII                           :   1 times => 0.201207% of total appearences
# Streptococcus_sp_I_G2                                       :   1 times => 0.201207% of total appearences
# Aneurinibacillus_aneurinilyticus_ATCC_12856                 :   2 times => 0.402414% of total appearences
# Enterococcus_phoeniculicola_ATCC_BAA_412                    :   1 times => 0.201207% of total appearences
# Staphylococcus_intermedius_ATCC_27335                       :   2 times => 0.402414% of total appearences
# Fusobacterium_russii_ATCC_25533                             :   1 times => 0.201207% of total appearences
# Clostridium_symbiosum_ATCC_14940                            :   1 times => 0.201207% of total appearences
# Staphylococcus_caprae_C87                                   :   2 times => 0.402414% of total appearences
# Enterococcus_caccae_ATCC_BAA_1240                           :   2 times => 0.402414% of total appearences
# Lactobacillus_vaginalis_ATCC_49540                          :   2 times => 0.402414% of total appearences
# Edwardsiella_tarda_FL6_60                                   :   1 times => 0.201207% of total appearences
# Lactobacillus_delbrueckii_subsp_bulgaricus_ATCC_11842       :   1 times => 0.201207% of total appearences
# Streptococcus_infantis_ATCC_700779                          :   2 times => 0.402414% of total appearences
# Clostridium_tyrobutyricum_DSM_2637                          :   1 times => 0.201207% of total appearences
# Clostridium_botulinum_E1_str_BoNT_E_Beluga                  :   1 times => 0.201207% of total appearences
# Peptostreptococcus_anaerobius_DSM_2949                      :   3 times => 0.603622% of total appearences
# Pseudomonas_aeruginosa_NCGM2_S1                             :   2 times => 0.402414% of total appearences
# Enterococcus_faecalis_TX0104                                :   1 times => 0.201207% of total appearences
# Lactobacillus_johnsonii_DPC_6026                            :   1 times => 0.201207% of total appearences
# Streptococcus_cristatus_ATCC_51100                          :   2 times => 0.402414% of total appearences
# Vibrio_furnissii_NCTC_11218                                 :   3 times => 0.603622% of total appearences
# Bacillus_mycoides_DSM_2048                                  :   2 times => 0.402414% of total appearences
# Clostridium_asparagiforme_DSM_15981                         :   1 times => 0.201207% of total appearences
# Streptococcus_peroris_ATCC_700780                           :   2 times => 0.402414% of total appearences
# Bacillus_halodurans_C_125                                   :   2 times => 0.402414% of total appearences
# Roseomonas_mucosa_ATCC_BAA_692                              :   2 times => 0.402414% of total appearences
# Lactobacillus_casei_casei_BL23                              :   1 times => 0.201207% of total appearences
# Streptococcus_lutetiensis_033                               :   2 times => 0.402414% of total appearences
# Lactobacillus_reuteri_MM2_3_                                :   1 times => 0.201207% of total appearences
# Bacillus_endophyticus_2102                                  :   2 times => 0.402414% of total appearences
# Listeria_grayi_DSM_20601                                    :   1 times => 0.201207% of total appearences
# Methanosphaera_stadtmanae_DSM_3091                          :   1 times => 0.201207% of total appearences
# Lactobacillus_fermentum_ATCC_14931                          :   1 times => 0.201207% of total appearences
# Streptococcus_gallolyticus_subsp_gallolyticus_ATCC_43143    :   2 times => 0.402414% of total appearences
# Streptococcus_dysgalactiae_subsp_dysgalactiae_ATCC_27957    :   2 times => 0.402414% of total appearences
# Aeromonas_veronii_B565                                      :   2 times => 0.402414% of total appearences
# Methyloversatilis_universalis_FAM5                          :   1 times => 0.201207% of total appearences
# Methylobacterium_radiotolerans_JCM_2831                     :   1 times => 0.201207% of total appearences
# Lactobacillus_iners_DSM_13335                               :   2 times => 0.402414% of total appearences
# Ralstonia_sp_5_7_47FAA                                      :   2 times => 0.402414% of total appearences
# Clostridium_sartagoforme_AAU1                               :   1 times => 0.201207% of total appearences
# Pseudomonas_monteilii_NBRC_103158                           :   3 times => 0.603622% of total appearences
# humans                                                      :   3 times => 0.603622% of total appearences
# Staphylococcus_xylosus_NJ                                   :   2 times => 0.402414% of total appearences
# Capnocytophaga_granulosa_ATCC_51502                         :   2 times => 0.402414% of total appearences
# Staphylococcus_xylosus_DMB3_Bh1                             :   2 times => 0.402414% of total appearences
# Listeria_monocytogenes_SLCC_2378                            :   1 times => 0.201207% of total appearences
# Enterococcus_gallinarum_EG2                                 :   2 times => 0.402414% of total appearences
# Listeria_monocytogenes_FSL_R2_561                           :   1 times => 0.201207% of total appearences
# Bacillus_thermoamylovorans                                  :   2 times => 0.402414% of total appearences
# Lactobacillus_gasseri_ATCC_33323                            :   1 times => 0.201207% of total appearences
# Capnocytophaga_sputigena_ATCC_33612                         :   2 times => 0.402414% of total appearences
# Clostridium_hylemonae_DSM_15053                             :   1 times => 0.201207% of total appearences
# Bacillus_pumilus_ATCC_7061                                  :   2 times => 0.402414% of total appearences
# Lactobacillus_curvatus_CRL_705                              :   2 times => 0.402414% of total appearences
# Ochrobactrum_anthropi_ATCC_49188                            :   2 times => 0.402414% of total appearences
# Bacillus_cereus_AH187_F4810_72                              :   2 times => 0.402414% of total appearences
# Pediococcus_acidilactici_7_4                                :   1 times => 0.201207% of total appearences
# Enterococcus_faecalis_TX2134                                :   1 times => 0.201207% of total appearences
# Streptococcus_thoraltensis_DSM_12221                        :   2 times => 0.402414% of total appearences
# Methyloversatilis_universalis_Fam50001                      :   2 times => 0.402414% of total appearences
# Paenibacillus_alvei_DSM_29                                  :   2 times => 0.402414% of total appearences
# Lactobacillus_salivarius_HO66_ATCC_11741                    :   1 times => 0.201207% of total appearences
# Bacillus_vallismortis_DV1_F_3                               :   2 times => 0.402414% of total appearences
# Pseudomonas_alcaliphila_34                                  :   3 times => 0.603622% of total appearences
# Lactobacillus_pentosus_KCA1                                 :   2 times => 0.402414% of total appearences
# Granulicatella_adiacens_ATCC_49175                          :   2 times => 0.402414% of total appearences
# Clostridium_celatum_DSM_1785                                :   1 times => 0.201207% of total appearences
# Bacillus_timonensis_JC401                                   :   1 times => 0.201207% of total appearences
# Oceanobacillus_picturae_strain_S1                           :   4 times => 0.804829% of total appearences
# Streptococcus_salivarius_JIM8777                            :   2 times => 0.402414% of total appearences
# Vibrio_parahaemolyticus_RIMD_2210633                        :   3 times => 0.603622% of total appearences
# Lactobacillus_fermentum_IFO_3956                            :   1 times => 0.201207% of total appearences
# Staphylococcus_capitis_CR0101                               :   2 times => 0.402414% of total appearences
# Enterococcus_faecalis_OG1RF_ATCC_47077                      :   1 times => 0.201207% of total appearences
# Streptococcus_sp_2_1_36FAA                                  :   1 times => 0.201207% of total appearences
# Paracoccus_yeei_ATCC_BAA_599                                :   2 times => 0.402414% of total appearences
# Gemella_sanguinis_ATCC700632                                :   2 times => 0.402414% of total appearences
# Streptococcus_infantarius_subsp_infantarius_ATCC_BAA_102    :   1 times => 0.201207% of total appearences
# Alcaligenes_faecalis_subsp_faecalis_NCIB_8687               :   1 times => 0.201207% of total appearences
# Methanobrevibacter_ruminantium_M1                           :   2 times => 0.402414% of total appearences
# Streptococcus_pseudopneumoniae_IS7493                       :   2 times => 0.402414% of total appearences
# Vibrio_fluvialis_560                                        :   3 times => 0.603622% of total appearences
# Burkholderia_cepacia_GG4                                    :   2 times => 0.402414% of total appearences
# Ureibacillus_thermosphaericus_str_Thermo_BF                 :   2 times => 0.402414% of total appearences
# Dietzia_cinnamea_P4                                         :   2 times => 0.402414% of total appearences
# Pseudomonas_nitroreducens_HBP1                              :   2 times => 0.402414% of total appearences
# Lactobacillus_delbrueckii_subsp_bulgaricus_ATCC_BAA_365     :   1 times => 0.201207% of total appearences
# Mycobacterium_avium_subsp_avium_ATCC_25291                  :   2 times => 0.402414% of total appearences
# Listeria_monocytogenes_SLCC_7179                            :   1 times => 0.201207% of total appearences
# Lactobacillus_plantarum_subsp_plantarum_ATCC_14917          :   1 times => 0.201207% of total appearences
# Bacillus_altitudinis_41KF2b                                 :   2 times => 0.402414% of total appearences
# Lactobacillus_casei_ATCC_334                                :   1 times => 0.201207% of total appearences
# Microbacterium_oleivorans_NBRC_103075                       :   1 times => 0.201207% of total appearences
# Listeria_monocytogenes_serotype_7_SLCC_2482                 :   1 times => 0.201207% of total appearences
# Candidatus_Nitrososphaera_gargensis_Ga9_2                   :   2 times => 0.402414% of total appearences
# Lactobacillus_animalis_KCTC_3501                            :   2 times => 0.402414% of total appearences
# Bordetella_hinzii_OH87_BAL007II                             :   1 times => 0.201207% of total appearences
# Lactobacillus_sakei_subsp_sakei_23K                         :   1 times => 0.201207% of total appearences
# Bacillus_fordii_DSM_16014                                   :   1 times => 0.201207% of total appearences
# Clostridium_symbiosum_WAL_14673                             :   1 times => 0.201207% of total appearences
# Lactobacillus_reuteri_MM4_1A_                               :   1 times => 0.201207% of total appearences
# Enterococcus_hirae_ATCC_9790                                :   2 times => 0.402414% of total appearences
# Acinetobacter_junii_SH205                                   :   2 times => 0.402414% of total appearences
# Staphylococcus_equorum_subsp_equorum_Mu2                    :   2 times => 0.402414% of total appearences
# Stenotrophomonas_maltophilia_D457                           :   2 times => 0.402414% of total appearences
# Lactobacillus_acidophilus_ATCC_4796                         :   1 times => 0.201207% of total appearences
# Streptococcus_uberis_0140J                                  :   2 times => 0.402414% of total appearences
# Streptococcus_sp_I_P16                                      :   1 times => 0.201207% of total appearences
# Fusobacterium_mortiferum_ATCC_9817                          :   1 times => 0.201207% of total appearences
# Kytococcus_sedentarius_DSM_20547                            :   2 times => 0.402414% of total appearences
# Lactobacillus_salivarius_salivarius_UCC118                  :   1 times => 0.201207% of total appearences
# Acinetobacter_haemolyticus_NIPH_261                         :   2 times => 0.402414% of total appearences
# Clostridium_glycolicum_ATCC_14880                           :   1 times => 0.201207% of total appearences
# Lactobacillus_buchneri_ATCC_11577                           :   1 times => 0.201207% of total appearences
# Salmonella_enterica_enterica_sv_Typhimurium_LT2             :   1 times => 0.201207% of total appearences
# Mycobacterium_fortuitum_subsp_fortuitum_DSM_46621           :   2 times => 0.402414% of total appearences
# Enterococcus_casseliflavus_ATCC_12755                       :   2 times => 0.402414% of total appearences
# Pediococcus_acidilactici_DSM_20284                          :   1 times => 0.201207% of total appearences
# Acidaminococcus_intestini_RyC_MR95                          :   1 times => 0.201207% of total appearences
# Leuconostoc_argentinum_KCTC_3773                            :   2 times => 0.402414% of total appearences
# Clostridium_beijerinckii_NCIMB_8052                         :   1 times => 0.201207% of total appearences
# Staphylococcus_pasteuri_SP1                                 :   2 times => 0.402414% of total appearences
# Streptococcus_sanguinis_SK36                                :   2 times => 0.402414% of total appearences
# Bacillus_flexus_27Col1_1E                                   :   1 times => 0.201207% of total appearences
# Brevibacillus_agri_5_2                                      :   1 times => 0.201207% of total appearences
# Arthrobacter_castelli_DSM_16402                             :   1 times => 0.201207% of total appearences
# Gemella_morbillorum_M424                                    :   2 times => 0.402414% of total appearences
# Lactobacillus_rhamnosus_GG_ATCC_53103                       :   1 times => 0.201207% of total appearences
# Lactobacillus_mucosae_LM1                                   :   2 times => 0.402414% of total appearences
# Gordonia_rubripertincta_NBRC_101908                         :   1 times => 0.201207% of total appearences
# Rhodococcus_equi_ATCC_33707                                 :   2 times => 0.402414% of total appearences
# Corynebacterium_kroppenstedtii_DSM_44385                    :   3 times => 0.603622% of total appearences
# Corynebacterium_amycolatum_SK46                             :   3 times => 0.603622% of total appearences
# Laribacter_hongkongensis_HLHK9                              :   2 times => 0.402414% of total appearences
# Lysinibacillus_sphaericus_C3_41                             :   2 times => 0.402414% of total appearences
# Bacillus_pseudofirmus_OF4                                   :   2 times => 0.402414% of total appearences
# Staphylococcus_warneri_SG1                                  :   2 times => 0.402414% of total appearences
# Brevibacillus_borstelensis_AK1                              :   2 times => 0.402414% of total appearences
# Streptococcus_australis_ATCC_700641                         :   2 times => 0.402414% of total appearences
# Listeria_monocytogenes_SLCC_2540                            :   1 times => 0.201207% of total appearences
# Lactobacillus_crispatus_125_2_CHN                           :   1 times => 0.201207% of total appearences
# Desulfovibrio_desulfuricans_subsp_desulfuricans_DSM_642     :   1 times => 0.201207% of total appearences
# Enterococcus_durans_ATCC_6056                               :   1 times => 0.201207% of total appearences
# Leuconostoc_gelidum_JB7                                     :   2 times => 0.402414% of total appearences
# Stenotrophomonas_rhizophila_PCA13                           :   2 times => 0.402414% of total appearences
# Brevibacillus_agri_BAB_2500                                 :   2 times => 0.402414% of total appearences
# Enterococcus_dispar_ATCC_51266                              :   1 times => 0.201207% of total appearences
# Corynebacterium_glucuronolyticum_ATCC_51867                 :   1 times => 0.201207% of total appearences
# Fusobacterium_varium_ATCC_27725                             :   1 times => 0.201207% of total appearences
# Brevundimonas_bacteroides_DSM_4726                          :   2 times => 0.402414% of total appearences
# Listeria_monocytogenes_4b_F2365                             :   1 times => 0.201207% of total appearences
# Lactobacillus_coleohominis_101_4_CHN                        :   2 times => 0.402414% of total appearences
# Blautia_producta_DSM_2950                                   :   1 times => 0.201207% of total appearences
# Lactobacillus_johnsonii_NCC_533                             :   1 times => 0.201207% of total appearences
# Lactobacillus_reuteri_CF48_3A_                              :   1 times => 0.201207% of total appearences
# Clostridium_sticklandii_DSM_519                             :   2 times => 0.402414% of total appearences
# Staphylococcus_saprophyticus_subsp_saprophyticus_ATCC_15305 :   2 times => 0.402414% of total appearences
# Brachybacterium_paraconglomeratum_LC44                      :   1 times => 0.201207% of total appearences
# Leptotrichia_buccalis_C_1013_b                              :   2 times => 0.402414% of total appearences
# Enterococcus_cecorum_DSM_20682                              :   2 times => 0.402414% of total appearences
# Cellulosimicrobium_cellulans_J36                            :   2 times => 0.402414% of total appearences
# Aeromonas_hydrophila_subsp_hydrophila_ATCC_7966             :   2 times => 0.402414% of total appearences
# Methanobrevibacter_smithii_ATCC_35061                       :   1 times => 0.201207% of total appearences
# Vibrio_mimicus_MB_451                                       :   1 times => 0.201207% of total appearences
# Sulfolobus_solfataricus_P2                                  :   2 times => 0.402414% of total appearences
# Lactobacillus_oris_F0423                                    :   2 times => 0.402414% of total appearences
# Silanimonas_lenta_DSM_16282                                 :   2 times => 0.402414% of total appearences
# Listeria_monocytogenes_J0161_FSL_R2_499                     :   1 times => 0.201207% of total appearences
# Lactobacillus_amylovorus_GRL_1112                           :   2 times => 0.402414% of total appearences
# Listeria_monocytogenes_Finland_1988                         :   1 times => 0.201207% of total appearences
# Aeromonas_jandaei_Riv2                                      :   2 times => 0.402414% of total appearences
# Bacillus_cereus_G9842                                       :   2 times => 0.402414% of total appearences
# Methanomassiliicoccus_luminyensis_B10                       :   2 times => 0.402414% of total appearences
# Staphylococcus_sciuri_subsp_sciuri_Z8                       :   2 times => 0.402414% of total appearences
# Streptococcus_equinus_ATCC_9812                             :   1 times => 0.201207% of total appearences
# Brevibacterium_linens_BL2                                   :   1 times => 0.201207% of total appearences
# Streptococcus_gordonii_str_Challis_substr_CH1               :   2 times => 0.402414% of total appearences
# Staphylococcus_cohnii_hu_01                                 :   2 times => 0.402414% of total appearences
# Streptococcus_parauberis_KCTC_11537                         :   2 times => 0.402414% of total appearences
# Clostridium_indolis_DSM_755                                 :   1 times => 0.201207% of total appearences
# Enterococcus_faecium_TX1330                                 :   1 times => 0.201207% of total appearences
# Citrobacter_amalonaticus_Y19                                :   1 times => 0.201207% of total appearences
# Streptococcus_vestibularis_F0396                            :   2 times => 0.402414% of total appearences
# Staphylococcus_arlettae_CVD059                              :   2 times => 0.402414% of total appearences
# Lactobacillus_hilgardii_ATCC_8290                           :   1 times => 0.201207% of total appearences
# Aeromonas_caviae_Ae398                                      :   2 times => 0.402414% of total appearences
# Bifidobacterium_mongoliense_DSM_21395                       :   2 times => 0.402414% of total appearences
# Bacillus_sonorensis_L12                                     :   2 times => 0.402414% of total appearences
# Kocuria_rhizophila_DC2201                                   :   1 times => 0.201207% of total appearences
# Granulicatella_elegans_ATCC_700633                          :   2 times => 0.402414% of total appearences
# Lactobacillus_acidophilus_NCFM                              :   1 times => 0.201207% of total appearences
# Methylobacterium_mesophilicum_SR1_6_6                       :   1 times => 0.201207% of total appearences
# Bradyrhizobium_elkanii_USDA_76                              :   3 times => 0.603622% of total appearences
# Micromonospora_aurantiaca_ATCC_27029                        :   3 times => 0.603622% of total appearences
# Pyramidobacter_piscolens_W5455                              :   1 times => 0.201207% of total appearences
# Staphylococcus_hominis_subsp_hominis_C80                    :   2 times => 0.402414% of total appearences
# Geobacillus_vulcani_PSS1                                    :   2 times => 0.402414% of total appearences
# Lactobacillus_paracasei_subsp_paracasei_8700_2              :   1 times => 0.201207% of total appearences
# Clostridium_cellobioparum_DSM_1351                          :   3 times => 0.603622% of total appearences
# Enterococcus_asini_ATCC_700915                              :   2 times => 0.402414% of total appearences
# Streptococcus_agalactiae_A909                               :   2 times => 0.402414% of total appearences
# Methylobacterium_populi_BJ001                               :   1 times => 0.201207% of total appearences
# Acinetobacter_pittii_ANC_4052                               :   2 times => 0.402414% of total appearences
# Rhodococcus_equi_NBRC_101255                                :   2 times => 0.402414% of total appearences
# Staphylococcus_pettenkoferi_VCU012                          :   2 times => 0.402414% of total appearences
# Lactobacillus_antri_DSM_16041                               :   1 times => 0.201207% of total appearences
# Bacteroides_graminisolvens_DSM_19988                        :   1 times => 0.201207% of total appearences
# Enterococcus_sp_7L76                                        :   1 times => 0.201207% of total appearences
# Acinetobacter_lwoffii_WJ10621                               :   2 times => 0.402414% of total appearences
# Blastococcus_massiliensis_AP3                               :   2 times => 0.402414% of total appearences
# Pseudomonas_oleovorans_MOIL14HWK12                          :   2 times => 0.402414% of total appearences
# Lactobacillus_rhamnosus_LMS2_1                              :   1 times => 0.201207% of total appearences
# Streptococcus_constellatus_subsp_constellatus_SK53          :   2 times => 0.402414% of total appearences
# Staphylococcus_capitis_QN1                                  :   2 times => 0.402414% of total appearences
# Lactobacillus_plantarum_WCFS1                               :   1 times => 0.201207% of total appearences
# Acidaminococcus_sp_D21                                      :   1 times => 0.201207% of total appearences
# Leuconostoc_mesenteroides_subsp_cremoris_ATCC_19254         :   1 times => 0.201207% of total appearences
# Bacillus_mojavensis_RO_H_1                                  :   2 times => 0.402414% of total appearences
# Flavonifractor_plautii_ATCC_29863                           :   2 times => 0.402414% of total appearences
# Lactobacillus_brevis_subsp_gravesensis_ATCC_27305           :   1 times => 0.201207% of total appearences
# Capnocytophaga_ochracea_DSM_7271                            :   2 times => 0.402414% of total appearences
# Coprococcus_catus_GD_7                                      :   1 times => 0.201207% of total appearences
# Staphylococcus_haemolyticus_JCSC1435                        :   2 times => 0.402414% of total appearences
# Weissella_paramesenteroides_ATCC_33313                      :   1 times => 0.201207% of total appearences
# Micrococcus_luteus_NCTC_2665                                :   1 times => 0.201207% of total appearences
# Rhodococcus_rhodochrous_ATCC_21198                          :   2 times => 0.402414% of total appearences
# Clostridium_sordellii_ATCC_9714                             :   2 times => 0.402414% of total appearences
# Staphylococcus_simulans_ACS_120_V_Sch1                      :   2 times => 0.402414% of total appearences
# Clostridium_citroniae_WAL_17108                             :   1 times => 0.201207% of total appearences
# Escherichia_albertii_TW07627                                :   1 times => 0.201207% of total appearences
# Curtobacterium_flaccumfaciens_UCD_AKU                       :   2 times => 0.402414% of total appearences
# Gordonia_terrae_C_6                                         :   1 times => 0.201207% of total appearences
# Brevibacillus_brevis_NBRC_100599                            :   2 times => 0.402414% of total appearences
# Lactobacillus_coryniformis_subsp_coryniformis_CECT_5711     :   2 times => 0.402414% of total appearences
# Listeria_monocytogenes_4a_L99                               :   1 times => 0.201207% of total appearences
# Lysinibacillus_fusiformis_ZB2                               :   3 times => 0.603622% of total appearences
# Dermacoccus_nishinomiyaensis                                :   1 times => 0.201207% of total appearences
# Dysgonomonas_gadei_ATCC_BAA_286                             :   1 times => 0.201207% of total appearences
# Streptococcus_oralis_Uo5                                    :   2 times => 0.402414% of total appearences
# Paenibacillus_graminis_C4D1M                                :   2 times => 0.402414% of total appearences
# Lactobacillus_helveticus_DSM_20075                          :   1 times => 0.201207% of total appearences
# Delftia_acidovorans_SPH_1                                   :   3 times => 0.603622% of total appearences
# Acinetobacter_johnsonii_SH046                               :   2 times => 0.402414% of total appearences
# Clostridium_saccharoperbutylacetonicum_N1_4_HMT             :   1 times => 0.201207% of total appearences
# Gordonia_terrae_NBRC_100016                                 :   1 times => 0.201207% of total appearences
# Lactobacillus_plantarum_JDM1                                :   1 times => 0.201207% of total appearences
# Bacillus_atrophaeus_ATCC_49822_1                            :   3 times => 0.603622% of total appearences
# Aerococcus_viridans_ATCC_11563                              :   2 times => 0.402414% of total appearences
# Acinetobacter_radioresistens_NIPH_2130                      :   2 times => 0.402414% of total appearences
# Pediococcus_pentosaceus_ATCC_25745                          :   2 times => 0.402414% of total appearences
# Streptococcus_constellatus_subsp_pharyngis_SK1060           :   2 times => 0.402414% of total appearences
# Bacillus_clausii_KSM_K16                                    :   2 times => 0.402414% of total appearences
# Nevskia_ramosa_DSM_11499                                    :   3 times => 0.603622% of total appearences
# Clostridium_paraputrificum_AGR2156                          :   1 times => 0.201207% of total appearences
# Brevibacterium_casei_S18                                    :   1 times => 0.201207% of total appearences
# Staphylococcus_vitulinus_F1028                              :   2 times => 0.402414% of total appearences
# Gemella_haemolysans_ATCC_10379                              :   2 times => 0.402414% of total appearences
# Clostridium_methoxybenzovorans_SR3                          :   1 times => 0.201207% of total appearences
# Faecalibacterium_prausnitzii_L2_6                           :   1 times => 0.201207% of total appearences
# Cloacibacillus_evryensis_DSM_19522                          :   1 times => 0.201207% of total appearences
# Brochothrix_thermosphacta_DSM_20171                         :   2 times => 0.402414% of total appearences
# Corynebacterium_propinquum_DSM_44285                        :   1 times => 0.201207% of total appearences
# ==================================
# {'allBacteria': ['Lactobacillus_ultunensis_DSM_16047',
#   'Enterococcus_faecalis_TX1322',
#   'Anaerobaculum_hydrogeniformans_OS1_ATCC_BAA_1850',
#   'Lactobacillus_ruminis_ATCC_25644',
#   'Pseudomonas_oleovorans_MOIL14HWK12',
#   'Fusobacterium_russii_ATCC_25533',
#   'Clostridium_botulinum_E1_str_BoNT_E_Beluga',
#   'Pseudomonas_aeruginosa_NCGM2_S1',
#   'Streptococcus_lutetiensis_033',
#   'Lactobacillus_reuteri_MM2_3_',
#   'Streptococcus_dysgalactiae_subsp_dysgalactiae_ATCC_27957',
#   'Lactobacillus_iners_DSM_13335',
#   'Clostridium_sartagoforme_AAU1',
#   'Staphylococcus_xylosus_NJ',
#   'Capnocytophaga_granulosa_ATCC_51502',
#   'Enterococcus_gallinarum_EG2',
#   'Capnocytophaga_sputigena_ATCC_33612',
#   'Clostridium_hylemonae_DSM_15053',
#   'Methyloversatilis_universalis_Fam50001',
#   'Weissella_cibaria_KACC_11862',
#   'Oceanobacillus_picturae_strain_S1',
#   'Vibrio_parahaemolyticus_RIMD_2210633',
#   'Streptococcus_infantarius_subsp_infantarius_ATCC_BAA_102',
#   'Lactobacillus_delbrueckii_subsp_bulgaricus_ATCC_BAA_365',
#   'Streptococcus_gordonii_str_Challis_substr_CH1',
#   'Lactobacillus_animalis_KCTC_3501',
#   'Bacillus_fordii_DSM_16014',
#   'Clostridium_symbiosum_WAL_14673',
#   'Lactobacillus_reuteri_MM4_1A_',
#   'Acinetobacter_junii_SH205',
#   'Streptococcus_anginosus_1_2_62CV',
#   'Laribacter_hongkongensis_HLHK9',
#   'Listeria_grayi_DSM_20601',
#   'Listeria_monocytogenes_FSL_R2_561',
#   'Leuconostoc_argentinum_KCTC_3773',
#   'Staphylococcus_pasteuri_SP1',
#   'Dietzia_cinnamea_P4',
#   'Gemella_morbillorum_M424',
#   'Gordonia_rubripertincta_NBRC_101908',
#   'Rhodococcus_equi_ATCC_33707',
#   'Lactobacillus_amylovorus_GRL_1112',
#   'Bacillus_pseudofirmus_OF4',
#   'Lactobacillus_crispatus_125_2_CHN',
#   'Brevundimonas_bacteroides_DSM_4726',
#   'Lactobacillus_johnsonii_NCC_533',
#   'Staphylococcus_warneri_SG1',
#   'Leptotrichia_buccalis_C_1013_b',
#   'Streptococcus_thermophilus_LMG_18311',
#   'Aeromonas_hydrophila_subsp_hydrophila_ATCC_7966',
#   'Lactobacillus_gastricus_PS3',
#   'Bifidobacterium_mongoliense_DSM_21395',
#   'Staphylococcus_vitulinus_F1028',
#   'Lactobacillus_plantarum_subsp_plantarum_ATCC_14917',
#   'Bacillus_infantis_NRRL_B_14911',
#   'Rhodococcus_equi_NBRC_101255',
#   'Clostridium_cellobioparum_DSM_1351',
#   'Enterococcus_asini_ATCC_700915',
#   'Lactobacillus_salivarius_HO66_ATCC_11741',
#   'Lactobacillus_antri_DSM_16041',
#   'Blastococcus_massiliensis_AP3',
#   'Streptococcus_constellatus_subsp_constellatus_SK53',
#   'Lactobacillus_gasseri_ATCC_33323',
#   'Capnocytophaga_ochracea_DSM_7271',
#   'Staphylococcus_intermedius_ATCC_27335',
#   'Lysinibacillus_fusiformis_ZB2',
#   'Dermacoccus_nishinomiyaensis',
#   'Enterococcus_durans_ATCC_6056',
#   'Lactobacillus_helveticus_DSM_20075',
#   'Acinetobacter_johnsonii_SH046',
#   'Clostridium_saccharoperbutylacetonicum_N1_4_HMT',
#   'Lactobacillus_plantarum_JDM1',
#   'Acinetobacter_radioresistens_NIPH_2130',
#   'Streptococcus_constellatus_subsp_pharyngis_SK1060',
#   'Bacillus_atrophaeus_ATCC_49822_1',
#   'Paenibacillus_graminis_C4D1M',
#   'Microbacterium_paraoxydans_77MFTsu3_2',
#   'Lactococcus_garvieae_ATCC_49156',
#   'Kurthia_massiliensis_JC30',
#   'Acinetobacter_calcoaceticus_PHEA_2',
#   'Lactobacillus_reuteri_F275_JCM_1112',
#   'Afipia_birgiae_34632',
#   'Streptococcus_mutans_ATCC_25175',
#   'Clostridium_asparagiforme_DSM_15981',
#   'Brevundimonas_diminuta_470_4',
#   'Streptococcus_mitis_NCTC_12261',
#   'Enterococcus_avium_ATCC_14025',
#   'Lactobacillus_acidophilus_ATCC_4796',
#   'Streptococcus_sp_I_G2',
#   'Clostridium_symbiosum_ATCC_14940',
#   'Staphylococcus_caprae_C87',
#   'Enterococcus_caccae_ATCC_BAA_1240',
#   'Lactobacillus_vaginalis_ATCC_49540',
#   'Silanimonas_lenta_DSM_16282',
#   'Enterococcus_faecalis_TX0104',
#   'Streptococcus_cristatus_ATCC_51100',
#   'Vibrio_furnissii_NCTC_11218',
#   'Streptococcus_peroris_ATCC_700780',
#   'Bacillus_halodurans_C_125',
#   'Roseomonas_mucosa_ATCC_BAA_692',
#   'Bacillus_endophyticus_2102',
#   'Salmonella_enterica_enterica_sv_Typhimurium_LT2',
#   'Ralstonia_sp_5_7_47FAA',
#   'Pseudomonas_monteilii_NBRC_103158',
#   'Staphylococcus_xylosus_DMB3_Bh1',
#   'Bacillus_thermoamylovorans',
#   'Bacillus_cereus_AH187_F4810_72',
#   'Pediococcus_acidilactici_7_4',
#   'Granulicatella_adiacens_ATCC_49175',
#   'Aneurinibacillus_aneurinilyticus_ATCC_12856',
#   'Streptococcus_salivarius_JIM8777',
#   'Enterococcus_faecalis_OG1RF_ATCC_47077',
#   'Methylobacterium_radiotolerans_JCM_2831',
#   'Paracoccus_yeei_ATCC_BAA_599',
#   'Vibrio_fluvialis_560',
#   'Ureibacillus_thermosphaericus_str_Thermo_BF',
#   'Streptococcus_sanguinis_SK36',
#   'Mycobacterium_avium_subsp_avium_ATCC_25291',
#   'Staphylococcus_simulans_ACS_120_V_Sch1',
#   'Bacillus_altitudinis_41KF2b',
#   'Microbacterium_oleivorans_NBRC_103075',
#   'Bordetella_hinzii_OH87_BAL007II',
#   'Lactobacillus_sakei_subsp_sakei_23K',
#   'Staphylococcus_equorum_subsp_equorum_Mu2',
#   'Stenotrophomonas_maltophilia_D457',
#   'Fusobacterium_mortiferum_ATCC_9817',
#   'Kytococcus_sedentarius_DSM_20547',
#   'Lactobacillus_salivarius_salivarius_UCC118',
#   'Lactobacillus_buchneri_ATCC_11577',
#   'Acidaminococcus_intestini_RyC_MR95',
#   'Lactobacillus_mucosae_LM1',
#   'Lysinibacillus_sphaericus_C3_41',
#   'Listeria_monocytogenes_SLCC_2540',
#   'Desulfovibrio_desulfuricans_subsp_desulfuricans_DSM_642',
#   'humans',
#   'Citrobacter_amalonaticus_Y19',
#   'Lactobacillus_reuteri_CF48_3A_',
#   'Staphylococcus_saprophyticus_subsp_saprophyticus_ATCC_15305',
#   'Enterococcus_cecorum_DSM_20682',
#   'Brevibacillus_borstelensis_AK1',
#   'Streptococcus_australis_ATCC_700641',
#   'Listeria_monocytogenes_Finland_1988',
#   'Streptococcus_parauberis_KCTC_11537',
#   'Clostridium_indolis_DSM_755',
#   'Enterococcus_faecium_TX1330',
#   'Methanomassiliicoccus_luminyensis_B10',
#   'Listeria_monocytogenes_4b_F2365',
#   'Granulicatella_elegans_ATCC_700633',
#   'Micromonospora_aurantiaca_ATCC_27029',
#   'Staphylococcus_hominis_subsp_hominis_C80',
#   'Escherichia_albertii_TW07627',
#   'Acinetobacter_lwoffii_WJ10621',
#   'Enterococcus_sp_7L76',
#   'Coprococcus_catus_GD_7',
#   'Staphylococcus_haemolyticus_JCSC1435',
#   'Bacillus_firmus_DS1',
#   'Aerococcus_viridans_ATCC_11563',
#   'Fusobacterium_varium_ATCC_27725',
#   'Leuconostoc_mesenteroides_subsp_cremoris_ATCC_19254',
#   'Curtobacterium_flaccumfaciens_UCD_AKU',
#   'Listeria_monocytogenes_4a_L99',
#   'Lactobacillus_coryniformis_subsp_coryniformis_CECT_5711',
#   'Staphylococcus_cohnii_hu_01',
#   'Nevskia_ramosa_DSM_11499',
#   'Lactobacillus_rhamnosus_GG_ATCC_53103',
#   'Porphyromonas_gingivalis_W83',
#   'Staphylococcus_lugdunensis_HKU09_01',
#   'Fusobacterium_ulcerans_ATCC_49185',
#   'Bacillus_vallismortis_DV1_F_3',
#   'Streptococcus_intermedius_JTH08',
#   'Lactobacillus_brevis_ATCC_367',
#   'Aeromonas_media_WS',
#   'Lactobacillus_acidophilus_NCFM',
#   'Blautia_producta_DSM_2950',
#   'Lactobacillus_paracasei_subsp_paracasei_ATCC_25302',
#   'Lactobacillus_amylolyticus_DSM_11664',
#   'Edwardsiella_tarda_FL6_60',
#   'Streptococcus_infantis_ATCC_700779',
#   'Peptostreptococcus_anaerobius_DSM_2949',
#   'Staphylococcus_capitis_CR0101',
#   'Methanosphaera_stadtmanae_DSM_3091',
#   'Aeromonas_veronii_B565',
#   'Bacillus_pumilus_ATCC_7061',
#   'Ochrobactrum_anthropi_ATCC_49188',
#   'Scardovia_inopinata_F0304',
#   'Pseudomonas_alcaliphila_34',
#   'Gemella_sanguinis_ATCC700632',
#   'Methanobrevibacter_ruminantium_M1',
#   'Pseudomonas_nitroreducens_HBP1',
#   'Lactobacillus_casei_ATCC_334',
#   'Lactobacillus_reuteri_SD2112_ATCC_55730',
#   'Burkholderia_cepacia_GG4',
#   'Streptococcus_sp_I_P16',
#   'Methyloversatilis_universalis_FAM5',
#   'Clostridium_glycolicum_ATCC_14880',
#   'Mycobacterium_fortuitum_subsp_fortuitum_DSM_46621',
#   'Enterococcus_casseliflavus_ATCC_12755',
#   'Pediococcus_acidilactici_DSM_20284',
#   'Lactobacillus_helveticus_DPC_4571',
#   'Gemella_sanguinis_M325',
#   'Staphylococcus_sciuri_subsp_sciuri_Z8',
#   'Corynebacterium_glucuronolyticum_ATCC_51867',
#   'Lactobacillus_coleohominis_101_4_CHN',
#   'Pediococcus_pentosaceus_ATCC_25745',
#   'Corynebacterium_propinquum_DSM_44285',
#   'Streptococcus_pseudopneumoniae_IS7493',
#   'Cellulosimicrobium_cellulans_J36',
#   'Methylobacterium_mesophilicum_SR1_6_6',
#   'Lactobacillus_oris_F0423',
#   'Listeria_monocytogenes_J0161_FSL_R2_499',
#   'Streptococcus_equinus_ATCC_9812',
#   'Aeromonas_caviae_Ae398',
#   'Kocuria_rhizophila_DC2201',
#   'Bacillus_cereus_G9842',
#   'Methylobacterium_populi_BJ001',
#   'Lactobacillus_rhamnosus_LMS2_1',
#   'Staphylococcus_capitis_QN1',
#   'Lactobacillus_plantarum_WCFS1',
#   'Enterococcus_phoeniculicola_ATCC_BAA_412',
#   'Micrococcus_luteus_NCTC_2665',
#   'Streptococcus_oralis_Uo5',
#   'Bacillus_clausii_KSM_K16',
#   'Weissella_paramesenteroides_ATCC_33313',
#   'Clostridium_methoxybenzovorans_SR3',
#   'Cloacibacillus_evryensis_DSM_19522',
#   'Brochothrix_thermosphacta_DSM_20171',
#   'Listeria_monocytogenes_serotype_7_SLCC_2482',
#   'Lactobacillus_johnsonii_DPC_6026',
#   'Brevibacterium_linens_BL2',
#   'Brevibacterium_massiliense_5401308',
#   'Streptococcus_sp_2_1_36FAA',
#   'Propionibacterium_propionicum_F0230a',
#   'Lactobacillus_jensenii_1153',
#   'Alcaligenes_faecalis_subsp_faecalis_NBRC_13111',
#   'Halococcus_morrhuae_DSM1307',
#   'Enterococcus_faecalis_V583',
#   'Streptococcus_parasanguinis_ATCC_903',
#   'Staphylococcus_epidermidis_ATCC_12228',
#   'Clostridium_symbiosum_WAL_14163',
#   'Lactobacillus_delbrueckii_subsp_bulgaricus_ATCC_11842',
#   'Clostridium_tyrobutyricum_DSM_2637',
#   'Bacillus_mycoides_DSM_2048',
#   'Candidatus_Nitrososphaera_gargensis_Ga9_2',
#   'Sulfolobus_solfataricus_P2',
#   'Lactobacillus_casei_casei_BL23',
#   'Streptococcus_agalactiae_A909',
#   'Streptococcus_gallolyticus_subsp_gallolyticus_ATCC_43143',
#   'Acinetobacter_pittii_ANC_4052',
#   'Weissella_confusa_LBAE_C39_2',
#   'Listeria_monocytogenes_SLCC_2378',
#   'Flavonifractor_plautii_ATCC_29863',
#   'Enterococcus_faecalis_TX2134',
#   'Clostridium_paraputrificum_AGR2156',
#   'Paenibacillus_alvei_DSM_29',
#   'Lactobacillus_pentosus_KCA1',
#   'Clostridium_celatum_DSM_1785',
#   'Bacillus_timonensis_JC401',
#   'Lactobacillus_fermentum_IFO_3956',
#   'Clostridium_beijerinckii_NCIMB_8052',
#   'Alcaligenes_faecalis_subsp_faecalis_NCIB_8687',
#   'Pyramidobacter_piscolens_W5455',
#   'Arthrobacter_castelli_DSM_16402',
#   'Listeria_monocytogenes_SLCC_7179',
#   'Enterococcus_hirae_ATCC_9790',
#   'Streptococcus_uberis_0140J',
#   'Staphylococcus_arlettae_CVD059',
#   'Acinetobacter_haemolyticus_NIPH_261',
#   'Bacillus_flexus_27Col1_1E',
#   'Corynebacterium_kroppenstedtii_DSM_44385',
#   'Corynebacterium_amycolatum_SK46',
#   'Vibrio_mimicus_MB_451',
#   'Streptococcus_vestibularis_F0396',
#   'Leuconostoc_gelidum_JB7',
#   'Stenotrophomonas_rhizophila_PCA13',
#   'Brevibacillus_agri_BAB_2500',
#   'Enterococcus_dispar_ATCC_51266',
#   'Lactobacillus_fermentum_ATCC_14931',
#   'Clostridium_sticklandii_DSM_519',
#   'Brachybacterium_paraconglomeratum_LC44',
#   'Methanobrevibacter_smithii_ATCC_35061',
#   'Brevibacillus_agri_5_2',
#   'Aeromonas_jandaei_Riv2',
#   'Lactobacillus_hilgardii_ATCC_8290',
#   'Bacillus_sonorensis_L12',
#   'Bradyrhizobium_elkanii_USDA_76',
#   'Geobacillus_vulcani_PSS1',
#   'Lactobacillus_paracasei_subsp_paracasei_8700_2',
#   'Staphylococcus_pettenkoferi_VCU012',
#   'Bacteroides_graminisolvens_DSM_19988',
#   'Acidaminococcus_sp_D21',
#   'Bacillus_mojavensis_RO_H_1',
#   'Lactobacillus_curvatus_CRL_705',
#   'Lactobacillus_brevis_subsp_gravesensis_ATCC_27305',
#   'Rhodococcus_rhodochrous_ATCC_21198',
#   'Clostridium_sordellii_ATCC_9714',
#   'Clostridium_citroniae_WAL_17108',
#   'Gordonia_terrae_C_6',
#   'Brevibacillus_brevis_NBRC_100599',
#   'Yersinia_pseudotuberculosis_YPIII',
#   'Dysgonomonas_gadei_ATCC_BAA_286',
#   'Delftia_acidovorans_SPH_1',
#   'Streptococcus_thoraltensis_DSM_12221',
#   'Gordonia_terrae_NBRC_100016',
#   'Brevibacterium_casei_S18',
#   'Gemella_haemolysans_ATCC_10379',
#   'Faecalibacterium_prausnitzii_L2_6'],
#  'appearancesBacteria': 497.0,
#  'bacterias': {'Acidaminococcus_intestini_RyC_MR95': [1, 0.002012072434607646],
#   'Acidaminococcus_sp_D21': [1, 0.002012072434607646],
#   'Acinetobacter_calcoaceticus_PHEA_2': [2, 0.004024144869215292],
#   'Acinetobacter_haemolyticus_NIPH_261': [2, 0.004024144869215292],
#   'Acinetobacter_johnsonii_SH046': [2, 0.004024144869215292],
#   'Acinetobacter_junii_SH205': [2, 0.004024144869215292],
#   'Acinetobacter_lwoffii_WJ10621': [2, 0.004024144869215292],
#   'Acinetobacter_pittii_ANC_4052': [2, 0.004024144869215292],
#   'Acinetobacter_radioresistens_NIPH_2130': [2, 0.004024144869215292],
#   'Aerococcus_viridans_ATCC_11563': [2, 0.004024144869215292],
#   'Aeromonas_caviae_Ae398': [2, 0.004024144869215292],
#   'Aeromonas_hydrophila_subsp_hydrophila_ATCC_7966': [2, 0.004024144869215292],
#   'Aeromonas_jandaei_Riv2': [2, 0.004024144869215292],
#   'Aeromonas_media_WS': [2, 0.004024144869215292],
#   'Aeromonas_veronii_B565': [2, 0.004024144869215292],
#   'Afipia_birgiae_34632': [3, 0.006036217303822937],
#   'Alcaligenes_faecalis_subsp_faecalis_NBRC_13111': [1, 0.002012072434607646],
#   'Alcaligenes_faecalis_subsp_faecalis_NCIB_8687': [1, 0.002012072434607646],
#   'Anaerobaculum_hydrogeniformans_OS1_ATCC_BAA_1850': [2,
#    0.004024144869215292],
#   'Aneurinibacillus_aneurinilyticus_ATCC_12856': [2, 0.004024144869215292],
#   'Arthrobacter_castelli_DSM_16402': [1, 0.002012072434607646],
#   'Bacillus_altitudinis_41KF2b': [2, 0.004024144869215292],
#   'Bacillus_atrophaeus_ATCC_49822_1': [3, 0.006036217303822937],
#   'Bacillus_cereus_AH187_F4810_72': [2, 0.004024144869215292],
#   'Bacillus_cereus_G9842': [2, 0.004024144869215292],
#   'Bacillus_clausii_KSM_K16': [2, 0.004024144869215292],
#   'Bacillus_endophyticus_2102': [2, 0.004024144869215292],
#   'Bacillus_firmus_DS1': [1, 0.002012072434607646],
#   'Bacillus_flexus_27Col1_1E': [1, 0.002012072434607646],
#   'Bacillus_fordii_DSM_16014': [1, 0.002012072434607646],
#   'Bacillus_halodurans_C_125': [2, 0.004024144869215292],
#   'Bacillus_infantis_NRRL_B_14911': [1, 0.002012072434607646],
#   'Bacillus_mojavensis_RO_H_1': [2, 0.004024144869215292],
#   'Bacillus_mycoides_DSM_2048': [2, 0.004024144869215292],
#   'Bacillus_pseudofirmus_OF4': [2, 0.004024144869215292],
#   'Bacillus_pumilus_ATCC_7061': [2, 0.004024144869215292],
#   'Bacillus_sonorensis_L12': [2, 0.004024144869215292],
#   'Bacillus_thermoamylovorans': [2, 0.004024144869215292],
#   'Bacillus_timonensis_JC401': [1, 0.002012072434607646],
#   'Bacillus_vallismortis_DV1_F_3': [2, 0.004024144869215292],
#   'Bacteroides_graminisolvens_DSM_19988': [1, 0.002012072434607646],
#   'Bifidobacterium_mongoliense_DSM_21395': [2, 0.004024144869215292],
#   'Blastococcus_massiliensis_AP3': [2, 0.004024144869215292],
#   'Blautia_producta_DSM_2950': [1, 0.002012072434607646],
#   'Bordetella_hinzii_OH87_BAL007II': [1, 0.002012072434607646],
#   'Brachybacterium_paraconglomeratum_LC44': [1, 0.002012072434607646],
#   'Bradyrhizobium_elkanii_USDA_76': [3, 0.006036217303822937],
#   'Brevibacillus_agri_5_2': [1, 0.002012072434607646],
#   'Brevibacillus_agri_BAB_2500': [2, 0.004024144869215292],
#   'Brevibacillus_borstelensis_AK1': [2, 0.004024144869215292],
#   'Brevibacillus_brevis_NBRC_100599': [2, 0.004024144869215292],
#   'Brevibacterium_casei_S18': [1, 0.002012072434607646],
#   'Brevibacterium_linens_BL2': [1, 0.002012072434607646],
#   'Brevibacterium_massiliense_5401308': [1, 0.002012072434607646],
#   'Brevundimonas_bacteroides_DSM_4726': [2, 0.004024144869215292],
#   'Brevundimonas_diminuta_470_4': [2, 0.004024144869215292],
#   'Brochothrix_thermosphacta_DSM_20171': [2, 0.004024144869215292],
#   'Burkholderia_cepacia_GG4': [2, 0.004024144869215292],
#   'Candidatus_Nitrososphaera_gargensis_Ga9_2': [2, 0.004024144869215292],
# ...
#   'Citrobacter_amalonaticus_Y19': [1, 0.002012072434607646],
#   'Cloacibacillus_evryensis_DSM_19522': [1, 0.002012072434607646],
#   'Clostridium_asparagiforme_DSM_15981': [1, 0.002012072434607646],
#   'Clostridium_beijerinckii_NCIMB_8052': [1, 0.002012072434607646],
#   'Clostridium_botulinum_E1_str_BoNT_E_Beluga': [1, 0.002012072434607646],
#   'Clostridium_celatum_DSM_1785': [1, 0.002012072434607646],
#   'Clostridium_cellobioparum_DSM_1351': [3, 0.006036217303822937],
#   'Clostridium_citroniae_WAL_17108': [1, 0.002012072434607646],
#   'Clostridium_glycolicum_ATCC_14880': [1, 0.002012072434607646],
#   'Clostridium_hylemonae_DSM_15053': [1, 0.002012072434607646],
#   'Clostridium_indolis_DSM_755': [1, 0.002012072434607646],
#   'Clostridium_methoxybenzovorans_SR3': [1, 0.002012072434607646],
#   'Clostridium_paraputrificum_AGR2156': [1, 0.002012072434607646],
#   'Clostridium_saccharoperbutylacetonicum_N1_4_HMT': [1, 0.002012072434607646],
#   'Clostridium_sartagoforme_AAU1': [1, 0.002012072434607646],
#   'Clostridium_sordellii_ATCC_9714': [2, 0.004024144869215292],
#   'Clostridium_sticklandii_DSM_519': [2, 0.004024144869215292],
#   'Clostridium_symbiosum_ATCC_14940': [1, 0.002012072434607646],
#   'Clostridium_symbiosum_WAL_14163': [1, 0.002012072434607646],
#   'Clostridium_symbiosum_WAL_14673': [1, 0.002012072434607646],
#   'Clostridium_tyrobutyricum_DSM_2637': [1, 0.002012072434607646],
#   'Coprococcus_catus_GD_7': [1, 0.002012072434607646],
#   'Corynebacterium_amycolatum_SK46': [3, 0.006036217303822937],
#   'Corynebacterium_glucuronolyticum_ATCC_51867': [1, 0.002012072434607646],
#   'Corynebacterium_kroppenstedtii_DSM_44385': [3, 0.006036217303822937],
#   'Corynebacterium_propinquum_DSM_44285': [1, 0.002012072434607646],
#   'Curtobacterium_flaccumfaciens_UCD_AKU': [2, 0.004024144869215292],
#   'Delftia_acidovorans_SPH_1': [3, 0.006036217303822937],
#   'Dermacoccus_nishinomiyaensis': [1, 0.002012072434607646],
#   'Desulfovibrio_desulfuricans_subsp_desulfuricans_DSM_642': [1,
#    0.002012072434607646],
#   'Dietzia_cinnamea_P4': [2, 0.004024144869215292],
#   'Dysgonomonas_gadei_ATCC_BAA_286': [1, 0.002012072434607646],
#   'Edwardsiella_tarda_FL6_60': [1, 0.002012072434607646],
#   'Enterococcus_asini_ATCC_700915': [2, 0.004024144869215292],
#   'Enterococcus_avium_ATCC_14025': [2, 0.004024144869215292],
#   'Enterococcus_caccae_ATCC_BAA_1240': [2, 0.004024144869215292],
#   'Enterococcus_casseliflavus_ATCC_12755': [2, 0.004024144869215292],
#   'Enterococcus_cecorum_DSM_20682': [2, 0.004024144869215292],
#   'Enterococcus_dispar_ATCC_51266': [1, 0.002012072434607646],
#   'Enterococcus_durans_ATCC_6056': [1, 0.002012072434607646],
#   'Enterococcus_faecalis_OG1RF_ATCC_47077': [1, 0.002012072434607646],
#   'Enterococcus_faecalis_TX0104': [1, 0.002012072434607646],
#   'Enterococcus_faecalis_TX1322': [1, 0.002012072434607646],
#   'Enterococcus_faecalis_TX2134': [1, 0.002012072434607646],
#   'Enterococcus_faecalis_V583': [1, 0.002012072434607646],
#   'Enterococcus_faecium_TX1330': [1, 0.002012072434607646],
#   'Enterococcus_gallinarum_EG2': [2, 0.004024144869215292],
#   'Enterococcus_hirae_ATCC_9790': [2, 0.004024144869215292],
#   'Enterococcus_phoeniculicola_ATCC_BAA_412': [1, 0.002012072434607646],
#   'Enterococcus_sp_7L76': [1, 0.002012072434607646],
#   'Escherichia_albertii_TW07627': [1, 0.002012072434607646],
#   'Faecalibacterium_prausnitzii_L2_6': [1, 0.002012072434607646],
#   'Flavonifractor_plautii_ATCC_29863': [2, 0.004024144869215292],
#   'Fusobacterium_mortiferum_ATCC_9817': [1, 0.002012072434607646],
#   'Fusobacterium_russii_ATCC_25533': [1, 0.002012072434607646],
#   'Fusobacterium_ulcerans_ATCC_49185': [1, 0.002012072434607646],
#   'Fusobacterium_varium_ATCC_27725': [1, 0.002012072434607646],
#   'Gemella_haemolysans_ATCC_10379': [2, 0.004024144869215292],
#   'Gemella_morbillorum_M424': [2, 0.004024144869215292],
#   'Gemella_sanguinis_ATCC700632': [2, 0.004024144869215292],
#   'Gemella_sanguinis_M325': [2, 0.004024144869215292],
#   'Geobacillus_vulcani_PSS1': [2, 0.004024144869215292],
#   'Gordonia_rubripertincta_NBRC_101908': [1, 0.002012072434607646],
#   'Gordonia_terrae_C_6': [1, 0.002012072434607646],
#   'Gordonia_terrae_NBRC_100016': [1, 0.002012072434607646],
#   'Granulicatella_adiacens_ATCC_49175': [2, 0.004024144869215292],
#   'Granulicatella_elegans_ATCC_700633': [2, 0.004024144869215292],
#   'Halococcus_morrhuae_DSM1307': [3, 0.006036217303822937],
#   'Kocuria_rhizophila_DC2201': [1, 0.002012072434607646],
#   'Kurthia_massiliensis_JC30': [2, 0.004024144869215292],
#   'Kytococcus_sedentarius_DSM_20547': [2, 0.004024144869215292],
#   'Lactobacillus_acidophilus_ATCC_4796': [1, 0.002012072434607646],
#   'Lactobacillus_acidophilus_NCFM': [1, 0.002012072434607646],
#   'Lactobacillus_amylolyticus_DSM_11664': [1, 0.002012072434607646],
#   'Lactobacillus_amylovorus_GRL_1112': [2, 0.004024144869215292],
#   'Lactobacillus_animalis_KCTC_3501': [2, 0.004024144869215292],
#   'Lactobacillus_antri_DSM_16041': [1, 0.002012072434607646],
#   'Lactobacillus_brevis_ATCC_367': [1, 0.002012072434607646],
#   'Lactobacillus_brevis_subsp_gravesensis_ATCC_27305': [1,
#    0.002012072434607646],
#   'Lactobacillus_buchneri_ATCC_11577': [1, 0.002012072434607646],
#   'Lactobacillus_casei_ATCC_334': [1, 0.002012072434607646],
#   'Lactobacillus_casei_casei_BL23': [1, 0.002012072434607646],
#   'Lactobacillus_coleohominis_101_4_CHN': [2, 0.004024144869215292],
#   'Lactobacillus_coryniformis_subsp_coryniformis_CECT_5711': [2,
#    0.004024144869215292],
#   'Lactobacillus_crispatus_125_2_CHN': [1, 0.002012072434607646],
#   'Lactobacillus_curvatus_CRL_705': [2, 0.004024144869215292],
#   'Lactobacillus_delbrueckii_subsp_bulgaricus_ATCC_11842': [1,
#    0.002012072434607646],
#   'Lactobacillus_delbrueckii_subsp_bulgaricus_ATCC_BAA_365': [1,
#    0.002012072434607646],
#   'Lactobacillus_fermentum_ATCC_14931': [1, 0.002012072434607646],
#   'Lactobacillus_fermentum_IFO_3956': [1, 0.002012072434607646],
#   'Lactobacillus_gasseri_ATCC_33323': [1, 0.002012072434607646],
#   'Lactobacillus_gastricus_PS3': [2, 0.004024144869215292],
#   'Lactobacillus_helveticus_DPC_4571': [2, 0.004024144869215292],
#   'Lactobacillus_helveticus_DSM_20075': [1, 0.002012072434607646],
#   'Lactobacillus_hilgardii_ATCC_8290': [1, 0.002012072434607646],
#   'Lactobacillus_iners_DSM_13335': [2, 0.004024144869215292],
#   'Lactobacillus_jensenii_1153': [2, 0.004024144869215292],
#   'Lactobacillus_johnsonii_DPC_6026': [1, 0.002012072434607646],
#   'Lactobacillus_johnsonii_NCC_533': [1, 0.002012072434607646],
#   'Lactobacillus_mucosae_LM1': [2, 0.004024144869215292],
#   'Lactobacillus_oris_F0423': [2, 0.004024144869215292],
#   'Lactobacillus_paracasei_subsp_paracasei_8700_2': [1, 0.002012072434607646],
#   'Lactobacillus_paracasei_subsp_paracasei_ATCC_25302': [1,
#    0.002012072434607646],
#   'Lactobacillus_pentosus_KCA1': [2, 0.004024144869215292],
#   'Lactobacillus_plantarum_JDM1': [1, 0.002012072434607646],
#   'Lactobacillus_plantarum_WCFS1': [1, 0.002012072434607646],
#   'Lactobacillus_plantarum_subsp_plantarum_ATCC_14917': [1,
#    0.002012072434607646],
#   'Lactobacillus_reuteri_CF48_3A_': [1, 0.002012072434607646],
#   'Lactobacillus_reuteri_F275_JCM_1112': [1, 0.002012072434607646],
#   'Lactobacillus_reuteri_MM2_3_': [1, 0.002012072434607646],
#   'Lactobacillus_reuteri_MM4_1A_': [1, 0.002012072434607646],
#   'Lactobacillus_reuteri_SD2112_ATCC_55730': [1, 0.002012072434607646],
#   'Lactobacillus_rhamnosus_GG_ATCC_53103': [1, 0.002012072434607646],
#   'Lactobacillus_rhamnosus_LMS2_1': [1, 0.002012072434607646],
#   'Lactobacillus_ruminis_ATCC_25644': [1, 0.002012072434607646],
#   'Lactobacillus_sakei_subsp_sakei_23K': [1, 0.002012072434607646],
#   'Lactobacillus_salivarius_HO66_ATCC_11741': [1, 0.002012072434607646],
#   'Lactobacillus_salivarius_salivarius_UCC118': [1, 0.002012072434607646],
#   'Lactobacillus_ultunensis_DSM_16047': [1, 0.002012072434607646],
#   'Lactobacillus_vaginalis_ATCC_49540': [2, 0.004024144869215292],
#   'Lactococcus_garvieae_ATCC_49156': [2, 0.004024144869215292],
#   'Laribacter_hongkongensis_HLHK9': [2, 0.004024144869215292],
#   'Leptotrichia_buccalis_C_1013_b': [2, 0.004024144869215292],
#   'Leuconostoc_argentinum_KCTC_3773': [2, 0.004024144869215292],
#   'Leuconostoc_gelidum_JB7': [2, 0.004024144869215292],
#   'Leuconostoc_mesenteroides_subsp_cremoris_ATCC_19254': [1,
#    0.002012072434607646],
#   'Listeria_grayi_DSM_20601': [1, 0.002012072434607646],
#   'Listeria_monocytogenes_4a_L99': [1, 0.002012072434607646],
#   'Listeria_monocytogenes_4b_F2365': [1, 0.002012072434607646],
#   'Listeria_monocytogenes_FSL_R2_561': [1, 0.002012072434607646],
#   'Listeria_monocytogenes_Finland_1988': [1, 0.002012072434607646],
#   'Listeria_monocytogenes_J0161_FSL_R2_499': [1, 0.002012072434607646],
#   'Listeria_monocytogenes_SLCC_2378': [1, 0.002012072434607646],
#   'Listeria_monocytogenes_SLCC_2540': [1, 0.002012072434607646],
#   'Listeria_monocytogenes_SLCC_7179': [1, 0.002012072434607646],
#   'Listeria_monocytogenes_serotype_7_SLCC_2482': [1, 0.002012072434607646],
#   'Lysinibacillus_fusiformis_ZB2': [3, 0.006036217303822937],
#   'Lysinibacillus_sphaericus_C3_41': [2, 0.004024144869215292],
#   'Methanobrevibacter_ruminantium_M1': [2, 0.004024144869215292],
#   'Methanobrevibacter_smithii_ATCC_35061': [1, 0.002012072434607646],
#   'Methanomassiliicoccus_luminyensis_B10': [2, 0.004024144869215292],
#   'Methanosphaera_stadtmanae_DSM_3091': [1, 0.002012072434607646],
#   'Methylobacterium_mesophilicum_SR1_6_6': [1, 0.002012072434607646],
#   'Methylobacterium_populi_BJ001': [1, 0.002012072434607646],
#   'Methylobacterium_radiotolerans_JCM_2831': [1, 0.002012072434607646],
#   'Methyloversatilis_universalis_FAM5': [1, 0.002012072434607646],
#   'Methyloversatilis_universalis_Fam50001': [2, 0.004024144869215292],
#   'Microbacterium_oleivorans_NBRC_103075': [1, 0.002012072434607646],
#   'Microbacterium_paraoxydans_77MFTsu3_2': [1, 0.002012072434607646],
#   'Micrococcus_luteus_NCTC_2665': [1, 0.002012072434607646],
#   'Micromonospora_aurantiaca_ATCC_27029': [3, 0.006036217303822937],
#   'Mycobacterium_avium_subsp_avium_ATCC_25291': [2, 0.004024144869215292],
#   'Mycobacterium_fortuitum_subsp_fortuitum_DSM_46621': [2,
#    0.004024144869215292],
#   'Nevskia_ramosa_DSM_11499': [3, 0.006036217303822937],
#   'Oceanobacillus_picturae_strain_S1': [4, 0.008048289738430584],
#   'Ochrobactrum_anthropi_ATCC_49188': [2, 0.004024144869215292],
#   'Paenibacillus_alvei_DSM_29': [2, 0.004024144869215292],
#   'Paenibacillus_graminis_C4D1M': [2, 0.004024144869215292],
#   'Paracoccus_yeei_ATCC_BAA_599': [2, 0.004024144869215292],
#   'Pediococcus_acidilactici_7_4': [1, 0.002012072434607646],
#   'Pediococcus_acidilactici_DSM_20284': [1, 0.002012072434607646],
#   'Pediococcus_pentosaceus_ATCC_25745': [2, 0.004024144869215292],
#   'Peptostreptococcus_anaerobius_DSM_2949': [3, 0.006036217303822937],
#   'Porphyromonas_gingivalis_W83': [2, 0.004024144869215292],
#   'Propionibacterium_propionicum_F0230a': [2, 0.004024144869215292],
#   'Pseudomonas_aeruginosa_NCGM2_S1': [2, 0.004024144869215292],
#   'Pseudomonas_alcaliphila_34': [3, 0.006036217303822937],
#   'Pseudomonas_monteilii_NBRC_103158': [3, 0.006036217303822937],
#   'Pseudomonas_nitroreducens_HBP1': [2, 0.004024144869215292],
#   'Pseudomonas_oleovorans_MOIL14HWK12': [2, 0.004024144869215292],
#   'Pyramidobacter_piscolens_W5455': [1, 0.002012072434607646],
#   'Ralstonia_sp_5_7_47FAA': [2, 0.004024144869215292],
#   'Rhodococcus_equi_ATCC_33707': [2, 0.004024144869215292],
#   'Rhodococcus_equi_NBRC_101255': [2, 0.004024144869215292],
#   'Rhodococcus_rhodochrous_ATCC_21198': [2, 0.004024144869215292],
#   'Roseomonas_mucosa_ATCC_BAA_692': [2, 0.004024144869215292],
#   'Salmonella_enterica_enterica_sv_Typhimurium_LT2': [1, 0.002012072434607646],
#   'Scardovia_inopinata_F0304': [2, 0.004024144869215292],
#   'Silanimonas_lenta_DSM_16282': [2, 0.004024144869215292],
#   'Staphylococcus_arlettae_CVD059': [2, 0.004024144869215292],
#   'Staphylococcus_capitis_CR0101': [2, 0.004024144869215292],
#   'Staphylococcus_capitis_QN1': [2, 0.004024144869215292],
#   'Staphylococcus_caprae_C87': [2, 0.004024144869215292],
#   'Staphylococcus_cohnii_hu_01': [2, 0.004024144869215292],
#   'Staphylococcus_epidermidis_ATCC_12228': [2, 0.004024144869215292],
#   'Staphylococcus_equorum_subsp_equorum_Mu2': [2, 0.004024144869215292],
#   'Staphylococcus_haemolyticus_JCSC1435': [2, 0.004024144869215292],
#   'Staphylococcus_hominis_subsp_hominis_C80': [2, 0.004024144869215292],
#   'Staphylococcus_intermedius_ATCC_27335': [2, 0.004024144869215292],
#   'Staphylococcus_lugdunensis_HKU09_01': [2, 0.004024144869215292],
#   'Staphylococcus_pasteuri_SP1': [2, 0.004024144869215292],
#   'Staphylococcus_pettenkoferi_VCU012': [2, 0.004024144869215292],
#   'Staphylococcus_saprophyticus_subsp_saprophyticus_ATCC_15305': [2,
#    0.004024144869215292],
#   'Staphylococcus_sciuri_subsp_sciuri_Z8': [2, 0.004024144869215292],
#   'Staphylococcus_simulans_ACS_120_V_Sch1': [2, 0.004024144869215292],
#   'Staphylococcus_vitulinus_F1028': [2, 0.004024144869215292],
#   'Staphylococcus_warneri_SG1': [2, 0.004024144869215292],
#   'Staphylococcus_xylosus_DMB3_Bh1': [2, 0.004024144869215292],
#   'Staphylococcus_xylosus_NJ': [2, 0.004024144869215292],
#   'Stenotrophomonas_maltophilia_D457': [2, 0.004024144869215292],
#   'Stenotrophomonas_rhizophila_PCA13': [2, 0.004024144869215292],
#   'Streptococcus_agalactiae_A909': [2, 0.004024144869215292],
#   'Streptococcus_anginosus_1_2_62CV': [1, 0.002012072434607646],
#   'Streptococcus_australis_ATCC_700641': [2, 0.004024144869215292],
#   'Streptococcus_constellatus_subsp_constellatus_SK53': [2,
#    0.004024144869215292],
#   'Streptococcus_constellatus_subsp_pharyngis_SK1060': [2,
#    0.004024144869215292],
#   'Streptococcus_cristatus_ATCC_51100': [2, 0.004024144869215292],
#   'Streptococcus_dysgalactiae_subsp_dysgalactiae_ATCC_27957': [2,
#    0.004024144869215292],
#   'Streptococcus_equinus_ATCC_9812': [1, 0.002012072434607646],
#   'Streptococcus_gallolyticus_subsp_gallolyticus_ATCC_43143': [2,
#    0.004024144869215292],
#   'Streptococcus_gordonii_str_Challis_substr_CH1': [2, 0.004024144869215292],
#   'Streptococcus_infantarius_subsp_infantarius_ATCC_BAA_102': [1,
#    0.002012072434607646],
#   'Streptococcus_infantis_ATCC_700779': [2, 0.004024144869215292],
#   'Streptococcus_intermedius_JTH08': [2, 0.004024144869215292],
#   'Streptococcus_lutetiensis_033': [2, 0.004024144869215292],
#   'Streptococcus_mitis_NCTC_12261': [2, 0.004024144869215292],
#   'Streptococcus_mutans_ATCC_25175': [2, 0.004024144869215292],
#   'Streptococcus_oralis_Uo5': [2, 0.004024144869215292],
#   'Streptococcus_parasanguinis_ATCC_903': [2, 0.004024144869215292],
#   'Streptococcus_parauberis_KCTC_11537': [2, 0.004024144869215292],
#   'Streptococcus_peroris_ATCC_700780': [2, 0.004024144869215292],
#   'Streptococcus_pseudopneumoniae_IS7493': [2, 0.004024144869215292],
#   'Streptococcus_salivarius_JIM8777': [2, 0.004024144869215292],
#   'Streptococcus_sanguinis_SK36': [2, 0.004024144869215292],
#   'Streptococcus_sp_2_1_36FAA': [1, 0.002012072434607646],
#   'Streptococcus_sp_I_G2': [1, 0.002012072434607646],
#   'Streptococcus_sp_I_P16': [1, 0.002012072434607646],
#   'Streptococcus_thermophilus_LMG_18311': [1, 0.002012072434607646],
#   'Streptococcus_thoraltensis_DSM_12221': [2, 0.004024144869215292],
#   'Streptococcus_uberis_0140J': [2, 0.004024144869215292],
#   'Streptococcus_vestibularis_F0396': [2, 0.004024144869215292],
#   'Sulfolobus_solfataricus_P2': [2, 0.004024144869215292],
#   'Ureibacillus_thermosphaericus_str_Thermo_BF': [2, 0.004024144869215292],
#   'Vibrio_fluvialis_560': [3, 0.006036217303822937],
#   'Vibrio_furnissii_NCTC_11218': [3, 0.006036217303822937],
#   'Vibrio_mimicus_MB_451': [1, 0.002012072434607646],
#   'Vibrio_parahaemolyticus_RIMD_2210633': [3, 0.006036217303822937],
#   'Weissella_cibaria_KACC_11862': [2, 0.004024144869215292],
#   'Weissella_confusa_LBAE_C39_2': [2, 0.004024144869215292],
#   'Weissella_paramesenteroides_ATCC_33313': [1, 0.002012072434607646],
#   'Yersinia_pseudotuberculosis_YPIII': [1, 0.002012072434607646],
#   'humans': [3, 0.006036217303822937]},
#  'humans': [3, 0.00019136314345856987]}
